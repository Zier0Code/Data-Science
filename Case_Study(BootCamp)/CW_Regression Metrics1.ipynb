# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Seaborn Settings
sns.set_style("whitegrid")
sns.set_context("poster")
sns.set(color_codes=True)

# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
df=pd.read_csv("C:\\Users\\Avila\\OneDrive\\Desktop\\csv files\\angelo avila - Ecommerce Customers.csv")
df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent
# 0           587.951054
# 1           392.204933
# 2           487.547505
# 3           581.852344
# 4           599.406092

# %%
df.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
df.corr()
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              1.000000    -0.027826        -0.034987
# Time on App                     -0.027826     1.000000         0.082388
# Time on Website                 -0.034987     0.082388         1.000000
# Length of Membership             0.060247     0.029143        -0.047582
# Yearly Amount Spent              0.355088     0.499328        -0.002641
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length               0.060247             0.355088
# Time on App                       0.029143             0.499328
# Time on Website                  -0.047582            -0.002641
# Length of Membership              1.000000             0.809084
# Yearly Amount Spent               0.809084             1.000000

# %%
mask = np.triu(np.ones_like(df.corr(), dtype=bool))

sns.heatmap(df.corr(),annot=True, mask=mask)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
#Figure size
plt.figure(figsize = (5,5))

#Labels
plt.xlabel('Time on Website')
plt.ylabel('Yearly Amount Spent')
plt.title('Time on Website vs. Yearly Amount Spent')

sns.regplot(x =a_train, y = b_train)
# Out:
# <AxesSubplot:title={'center':'Time on Website vs. Yearly Amount Spent'}, xlabel='Time on Website', ylabel='Yearly Amount Spent'>

# %%
a = df['Time on Website']
b = df['Yearly Amount Spent']

len(a), len(b)
# Out:
# (500, 500)

# %%
a.shape, b.shape
# Out:
# ((500,), (500,))

# %%
a_reshape = a.values.reshape(-1,1)
b_reshape = b.values.reshape(-1,1)

a_reshape.shape, b_reshape.shape
# Out:
# ((500, 1), (500, 1))

# %%
a_train, a_test, b_train, b_test = train_test_split(a_reshape, b_reshape, test_size=0.2, random_state=5)

a_train.shape, a_test.shape, b_train.shape, b_test.shape
# Out:
# ((400, 1), (100, 1), (400, 1), (100, 1))

# %%
linreg = LinearRegression()
linreg.fit(a_train,b_train)
# Out:
# LinearRegression()

# %%
b_pred = linreg.predict(a_test)
b_pred[0]
# Out:
# array([496.36220778])

# %% [markdown]
# <p style="background:black">
# <code style="background:black;color:black">
# </code>
# </p>

# %% [markdown]
# ***R Squared***

# %%
R2 =r2_score(b_test,b_pred) 
R2
# Out:
# -0.011373203058985037

# %% [markdown]
# <p style="background:black">
# <code style="background:black;color:black">
# </code>
# </p>

# %% [markdown]
# ***Mean Absolute Error (MAE)***

# %%
MAE=mean_absolute_error(b_test,b_pred)
MAE
# Out:
# 56.174350535908644

# %%
def mape(b_true, b_pred):

    #MAPE
    mape = np.mean(np.abs(b_pred - b_true)/np.abs(b_true))
    
    return mape

# %% [markdown]
# <p style="background:black">
# <code style="background:black;color:black">
# </code>
# </p>

# %% [markdown]
# ***Mean Absolute Percentage Error (MAPE)***

# %%
MAPE=mape(b_test,b_pred)
MAPE
# Out:
# 0.11448347530185977

# %% [markdown]
# <p style="background:black">
# <code style="background:black;color:black">
# </code>
# </p>

# %% [markdown]
# ***Root Mean Squared Error (RMSE)***

# %%
RMSE=np.sqrt(mean_squared_error(b_test,b_pred)) #RMSE
RMSE
# Out:
# 76.93948933532498

# %% [markdown]
# <p style="background:black">
# <code style="background:black;color:black">
# </code>
# </p>

# %% [markdown]
# ***Mean Squared Error (MSE)***

# %%
MSE=mean_squared_error(b_test,b_pred)
MSE
# Out:
# 5919.685019180585

# %% [markdown]
# <p style="background:black">
# <code style="background:black;color:black">
# </code>
# </p>

# %%
print("R^2: "+str(R2))
print("Mean Absolute Error: "+str(MAE)) 
print("Mean Absolute Percentage Error: "+str(MAPE))
print("Mean Squared Error: "+str(MSE))
print("Root Mean Squared Error: "+str(RMSE))
# Out:
# R^2: -0.011373203058985037
# Mean Absolute Error: 56.174350535908644
# Mean Absolute Percentage Error: 0.11448347530185977
# Mean Squared Error: 5919.685019180585
# Root Mean Squared Error: 76.93948933532498

# %% [markdown]
# <p style="background:black">
# <code style="background:black;color:black">
# </code>
# </p>
