# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
link= 'https://en.wikipedia.org/wiki/One_Piece'

# %%
wiki_res=requests.get(link)

# %%
wiki_code=wiki_res.content

# %%
wiki_code
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>One Piece - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"a0eda258-9f63-460c-9c81-c4f72a6791b3","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"One_Piece","wgTitle":"One Piece","wgCurRevisionId":1109111814,"wgRevisionId":1109111814,"wgArticleId":360759,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages with non-numeric formatnum arguments","Articles containing Japanese-language text","CS1 Japanese-language sources (ja)","CS1 uses Japanese-language scr
# ...

# %%
soup = BeautifulSoup(wiki_code,'html.parser')

# %%
soup1=soup.find_all('h1',class_='firstHeading mw-first-heading')
soup1
# Out:
# [<h1 class="firstHeading mw-first-heading" id="firstHeading"><i>One Piece</i></h1>]

# %%
soup1[0].text
# Out:
# 'One Piece'

# %%
type(soup1)
# Out:
# bs4.element.ResultSet

# %%
soup2=soup.find_all('span',class_='mw-headline')
soup2
# Out:
# [<span class="mw-headline" id="Premise">Premise</span>,
#  <span class="mw-headline" id="Production">Production</span>,
#  <span class="mw-headline" id="Concept_and_creation">Concept and creation</span>,
#  <span class="mw-headline" id="Development">Development</span>,
#  <span class="mw-headline" id="Conclusion">Conclusion</span>,
#  <span class="mw-headline" id="Publication">Publication</span>,
#  <span class="mw-headline" id="Main_series">Main series</span>,
#  <span class="mw-headline" id="Spin-offs_and_crossovers">Spin-offs and crossovers</span>,
#  <span class="mw-headline" id="Related_media">Related media</span>,
#  <span class="mw-headline" id="Festival_films_and_original_video_animation">Festival films and original video animation</span>,
#  <span class="mw-headline" id="TV_series">TV series</span>,
#  <span class="mw-headline" id="Anime_series">Anime series</span>,
#  <span class="mw-headline" id="Live-action_series">Live-action series</span>,
# ...

# %%
soup2[2].text
# Out:
# 'Concept and creation'

# %% [markdown]
# ### Monkeypox

# %%
link = 'https://www.who.int/health-topics/monkeypox#tab=tab_1'

# %%
response =requests.get(link)
response
# Out:
# <Response [200]>

# %%
html_mp=response.content
html_mp
# Out:
# b' <!DOCTYPE html> <html lang="en"> <head>  <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" /> <meta charset="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1"><title>\r\n\tMonkeypox\r\n</title> <link rel="shortcut icon" href="/favicon.ico"> <link rel="manifest" href="/manifest.json"> <link rel="apple-touch-icon" href="/apple-touch-icon-precomposed.png"> <meta name="theme-color" content="#007eb4" /><link href="//use.fontawesome.com/releases/v5.0.10/css/all.css" rel="stylesheet" type="text/css" /> <link rel=\'stylesheet\' href=\'/ResourcePackages/WHO/assets/dist/styles/grid.min.css?v=14.0.7729.14971\'>  <link rel=\'stylesheet\' href=\'/ResourcePackages/WHO/assets/dist/styles/origin.min.css?v=14.0.7729.14971\'><link rel=\'stylesheet\' href=\'/ResourcePackages/WHO/assets/dist/styles/main.min.css?v=14.0.7729.14971\'> <link rel=\'stylesheet\' href=\'/ResourcePackages/WHO/assets/dist/styles/print.min.css?v=14.0.7729.14971\' media=\'print\'>\n<script
# ...

# %% [markdown]
# ## Overview

# %%
soup = BeautifulSoup(html_mp,'html.parser')

# %%
title_code=soup.find_all('h1','dynamic-content__title-text')
title_code
# Out:
# [<h1 class="dynamic-content__title-text">Monkeypox</h1>]

# %%
mp_title=title_code[0].text
mp_title
# Out:
# 'Monkeypox'

# %%
mp_p=soup.find_all('div','sf_colsOut tabContent')

# %%
mp_p1=mp_p[0].text
mp_p2=mp_p[1].text
mp_p3=mp_p[2].text

# %%
print(mp_title)
print('\n''Overview')
print(mp_p1)
print(mp_p2)
print(mp_p3)
# Out:
# Monkeypox
#
# Overview
#
#
# Monkeypox virus is an orthopoxvirus that causes a disease with symptoms similar, but less severe, to smallpox. While smallpox was eradicated in 1980, monkeypox continues to occur in countries of central and west Africa. Two distinct clade are identified: the west African clade and the Congo Basin clade, also known as the central African clade.Monkeypox is a zoonosis: a disease that is transmitted from animals to humans. Cases are often found close to tropical rainforests where there are animals that carry the virus. Evidence of monkeypox virus infection has been found in animals including
# squirrels, Gambian poached rats, dormice, different species of monkeys and others.
# Human-to-human transmission is limited, with the longest documented chain of transmission being 6 generations, meaning that the last person to be infected in this chain was 6 links away from the original sick person. It can be transmitted through
# ...

# %%
print(mp_symp[1])
# Out:
# <div class="sf_colsOut tabContent" data-placeholder-label="Tab contents" data-sf-element="Tab contents">
# <div class="sf_colsIn">
# <p>Monkeypox presents with fever, an extensive characteristic rash and usually swollen lymph nodes. It is important to distinguish monkeypox from other illnesses such as chickenpox, measles, bacterial skin infections, scabies, syphilis and medication-associated
# allergies.
# </p><p>The incubation period of monkeypox can range from 5 to 21 days. The febrile stage of illness usually lasts 1 to 3 days with symptoms including fever, intense headache, lymphadenopathy (swelling of the lymph nodes), back pain, myalgia (muscle
# ache), and an intense asthenia (lack of energy). The febrile stage is followed by the skin eruption stage, lasting for 2 to 4 weeks. Lesions evolve from macules (lesions with a flat base) to papules (raised firm painful lesions) to vesicles (filled
# with clear fluid) to pustules (filled with pus), followed by scabs or crusts.
# ...

# %% [markdown]
# ## Symptom

# %%
mp_symp=soup.find_all('div','sf_colsOut tabContent')

# %%
mp_symp_p1=mp_symp[0].text
mp_symp_p1
# Out:
# '\n\nMonkeypox virus is an orthopoxvirus that causes a disease with symptoms similar, but less severe, to smallpox. While smallpox was eradicated in 1980, monkeypox continues to occur in countries of central and west Africa.\xa0Two distinct clade are identified: the west African clade and the Congo Basin clade, also known as the central African clade.Monkeypox is a zoonosis: a disease that is transmitted from animals to humans. Cases are often found close to tropical rainforests where there are animals that carry the virus. Evidence of monkeypox virus infection has been found in animals including\nsquirrels, Gambian poached rats, dormice, different species of monkeys and others.\xa0\nHuman-to-human transmission is limited, with the longest documented chain of transmission being 6 generations, meaning that the last person to be infected in this chain was 6 links away from the original sick person. It can be transmitted through\ncontact with bodily fluids, lesions on the skin or on int
# ...

# %%
mp_symp_p2=mp_symp[1].text
mp_symp_p3=mp_symp[2].text

# %%
print(mp_title)
print('\n''Symptoms')
print(mp_symp_p1)
print(mp_symp_p2)
print(mp_symp_p3)
# Out:
# Monkeypox
#
# Symptoms
#
#
# Monkeypox virus is an orthopoxvirus that causes a disease with symptoms similar, but less severe, to smallpox. While smallpox was eradicated in 1980, monkeypox continues to occur in countries of central and west Africa. Two distinct clade are identified: the west African clade and the Congo Basin clade, also known as the central African clade.Monkeypox is a zoonosis: a disease that is transmitted from animals to humans. Cases are often found close to tropical rainforests where there are animals that carry the virus. Evidence of monkeypox virus infection has been found in animals including
# squirrels, Gambian poached rats, dormice, different species of monkeys and others.
# Human-to-human transmission is limited, with the longest documented chain of transmission being 6 generations, meaning that the last person to be infected in this chain was 6 links away from the original sick person. It can be transmitted through
# ...
